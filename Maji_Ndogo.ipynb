# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/ExploreAI_logos/Logo blue_dark.png"  style="width:25px" align="right";/>
# </div>

# %% [markdown]
# # Integrated project notebook

# %% [markdown]
# ## Connecting to our MySQL database
#
# Using our `Access_to_Basic_Services` table in our `united_nations` database we created in MySQL Workbench, we want to answer some questions about our dataset. We can apply the same queries we used in MySQL Workbench in this notebook if we connect to our MySQL server by running the cells below.

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook. 
# If you get an error here, make sure that mysql and pymysql are installed correctly. 

# %load_ext sql

# %%
# Establish a connection to the local database using the '%sql' magic command.
# Replace 'password' with our connection password and `db_name` with our database name. 
# If you get an error here, please make sure the database name or password is correct.

# %sql mysql+pymysql://root:password@localhost:3306/md_water_services

# %% [markdown]
# # Integrated Project Maji Ndogo Part 1

# %% [markdown]
# ### Task 1: Get to know the data

# %%
# %%sql
#
# SHOW TABLES;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 9 rows affected.
# [('data_dictionary',),
#  ('employee',),
#  ('global_water_access',),
#  ('location',),
#  ('visits',),
#  ('water_quality',),
#  ('water_source',),
#  ('well_pollution',),
#  ('well_pollution_copy',)]

# %%
# %%sql
#
# SELECT *
# FROM location
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 5 rows affected.
# [('AkHa00000', '2 Addis Ababa Road', 'Akatsi', 'Harare', 'Urban'),
#  ('AkHa00001', '10 Addis Ababa Road', 'Akatsi', 'Harare', 'Urban'),
#  ('AkHa00002', '9 Addis Ababa Road', 'Akatsi', 'Harare', 'Urban'),
#  ('AkHa00003', '139 Addis Ababa Road', 'Akatsi', 'Harare', 'Urban'),
#  ('AkHa00004', '17 Addis Ababa Road', 'Akatsi', 'Harare', 'Urban')]

# %%
# %%sql
#
# SELECT *
# FROM visits
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 5 rows affected.
# [(0, 'SoIl32582', 'SoIl32582224', datetime.datetime(2021, 1, 1, 9, 10), 1, 15, 12),
#  (1, 'KiRu28935', 'KiRu28935224', datetime.datetime(2021, 1, 1, 9, 17), 1, 0, 46),
#  (2, 'HaRu19752', 'HaRu19752224', datetime.datetime(2021, 1, 1, 9, 36), 1, 62, 40),
#  (3, 'AkLu01628', 'AkLu01628224', datetime.datetime(2021, 1, 1, 9, 53), 1, 0, 1),
#  (4, 'AkRu03357', 'AkRu03357224', datetime.datetime(2021, 1, 1, 10, 11), 1, 28, 14)]

# %% [markdown]
# ### Task 2:Dive into the water sources:

# %%
# %%sql
#
# SELECT DISTINCT type_of_water_source
# FROM water_source;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 5 rows affected.
# [('tap_in_home',),
#  ('tap_in_home_broken',),
#  ('well',),
#  ('shared_tap',),
#  ('river',)]

# %% [markdown]
# ### Task 3: Unpack the visits to water sources:

# %%
# %%sql
#
# SELECT *
# FROM visits
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 5 rows affected.
# [(0, 'SoIl32582', 'SoIl32582224', datetime.datetime(2021, 1, 1, 9, 10), 1, 15, 12),
#  (1, 'KiRu28935', 'KiRu28935224', datetime.datetime(2021, 1, 1, 9, 17), 1, 0, 46),
#  (2, 'HaRu19752', 'HaRu19752224', datetime.datetime(2021, 1, 1, 9, 36), 1, 62, 40),
#  (3, 'AkLu01628', 'AkLu01628224', datetime.datetime(2021, 1, 1, 9, 53), 1, 0, 1),
#  (4, 'AkRu03357', 'AkRu03357224', datetime.datetime(2021, 1, 1, 10, 11), 1, 28, 14)]

# %% [markdown]
# Retrieve records where time in queue is >= 500 ie waiting for 8 hours to queue for water

# %%
# %%sql
#
# SELECT *
# FROM visits
# WHERE time_in_queue >= 500
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 5 rows affected.
# [(899, 'SoRu35083', 'SoRu35083224', datetime.datetime(2021, 1, 16, 10, 14), 6, 515, 28),
#  (2304, 'SoKo33124', 'SoKo33124224', datetime.datetime(2021, 2, 6, 7, 53), 5, 512, 16),
#  (2315, 'KiRu26095', 'KiRu26095224', datetime.datetime(2021, 2, 6, 14, 32), 3, 529, 8),
#  (3206, 'SoRu38776', 'SoRu38776224', datetime.datetime(2021, 2, 20, 15, 3), 5, 509, 46),
#  (3701, 'HaRu19601', 'HaRu19601224', datetime.datetime(2021, 2, 27, 12, 53), 3, 504, 0)]

# %% [markdown]
# ### Task 4: Assess the quality of water sources

# %%
# %%sql
#
# SELECT *
# FROM water_quality
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 5 rows affected.
# [(0, 0, 1), (1, 1, 1), (2, 5, 1), (3, 10, 1), (4, 4, 1)]

# %%
# %%sql
#
# SELECT *
# FROM water_quality
# WHERE subjective_quality_score = 10 AND visit_count = 2
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 5 rows affected.
# [(59, 10, 2), (137, 10, 2), (269, 10, 2), (363, 10, 2), (378, 10, 2)]

# %% [markdown]
# ### Task 5: Investigate pollution issues:

# %%
# %%sql
#
# SELECT *
# FROM well_pollution
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 5 rows affected.
# [('KiRu28935224', datetime.datetime(2021, 1, 4, 9, 17), 'Bacteria: Giardia Lamblia', 0.0, 495.898, 'Contaminated: Biological'),
#  ('AkLu01628224', datetime.datetime(2021, 1, 4, 9, 53), 'Bacteria: E. coli', 0.0, 6.09608, 'Contaminated: Biological'),
#  ('HaZa21742224', datetime.datetime(2021, 1, 4, 10, 37), 'Inorganic contaminants: Zinc, Zinc, Lead, Cadmium', 2.715, 0.0, 'Contaminated: Chemical'),
#  ('HaRu19725224', datetime.datetime(2021, 1, 4, 11, 4), 'Clean', 0.0288593, 9.56996e-05, 'Clean'),
#  ('SoRu35703224', datetime.datetime(2021, 1, 4, 11, 29), 'Bacteria: E. coli', 0.0, 22.5009, 'Contaminated: Biological')]

# %%
# %%sql
#
# SELECT DISTINCT(description) as 'Water contamination classification'
# FROM well_pollution
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 5 rows affected.
# [('Bacteria: Giardia Lamblia',),
#  ('Bacteria: E. coli',),
#  ('Inorganic contaminants: Zinc, Zinc, Lead, Cadmium',),
#  ('Clean',),
#  ('Inorganic contaminants: Cadmium',)]

# %% [markdown]
# Identify records that mistakenly have the word Clean in the description and biological value is greater than 0.01

# %%
# %%sql
#
# SELECT *
# FROM well_pollution
# WHERE description LIKE 'Clean%' AND biological > 0.01
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 0 rows affected.
# []

# %% [markdown]
# The second issue we need to fix is in our results column. We need to update the reults column from Clean to Contaminated: Biological where the biological column has a greater value than 0.01

# %%
# %%sql
#
# SELECT *
# FROM well_pollution
# WHERE results = 'Clean' AND biological > 0.01
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 0 rows affected.
# []

# %%
# %%sql
#
# CREATE TABLE md_water_services.well_pollution_copy AS(
#     SELECT *
#     FROM md_water_services.well_pollution
# )
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# (pymysql.err.OperationalError) (1050, "Table 'well_pollution_copy' already exists")
# [SQL: CREATE TABLE md_water_services.well_pollution_copy AS(
#     SELECT *
#     FROM md_water_services.well_pollution
# )]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %%
# %%sql
#
# SHOW TABLES;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 9 rows affected.
# [('data_dictionary',),
#  ('employee',),
#  ('global_water_access',),
#  ('location',),
#  ('visits',),
#  ('water_quality',),
#  ('water_source',),
#  ('well_pollution',),
#  ('well_pollution_copy',)]

# %%
# %%sql
#
# SELECT *
# FROM well_pollution_copy
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 5 rows affected.
# [('KiRu28935224', datetime.datetime(2021, 1, 4, 9, 17), 'Bacteria: Giardia Lamblia', 0.0, 495.898, 'Contaminated: Biological'),
#  ('AkLu01628224', datetime.datetime(2021, 1, 4, 9, 53), 'Bacteria: E. coli', 0.0, 6.09608, 'Contaminated: Biological'),
#  ('HaZa21742224', datetime.datetime(2021, 1, 4, 10, 37), 'Inorganic contaminants: Zinc, Zinc, Lead, Cadmium', 2.715, 0.0, 'Contaminated: Chemical'),
#  ('HaRu19725224', datetime.datetime(2021, 1, 4, 11, 4), 'Clean', 0.0288593, 9.56996e-05, 'Clean'),
#  ('SoRu35703224', datetime.datetime(2021, 1, 4, 11, 29), 'Bacteria: E. coli', 0.0, 22.5009, 'Contaminated: Biological')]

# %%
# %%sql
#
# UPDATE well_pollution_copy
# SET description = 'Bacteria: E. coli' WHERE description = 'Clean Bacteria: E. coli';
#
# UPDATE well_pollution_copy
# SET description = 'Bacteria: Giardia Lamblia' WHERE description = 'Clean Bacteria: Giardia Lamblia';
#
# UPDATE well_pollution_copy SET results = 'Contaminated: Biological' WHERE biological > 0.01 AND results = 'Clean';
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# []

# %%
# %%sql
#
# -- Test fixes (Should return 0 rows if successful)
# SELECT *
# FROM well_pollution_copy
# WHERE description LIKE 'Clean %' OR (results = 'Clean' AND biological > 0.01);
#
# DROP TABLE md_water_services.well_population_copy;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 0 rows affected.
# (pymysql.err.OperationalError) (1051, "Unknown table 'md_water_services.well_population_copy'")
# [SQL: DROP TABLE md_water_services.well_population_copy;]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %%
# %%sql
#
# SHOW TABLES;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 9 rows affected.
# [('data_dictionary',),
#  ('employee',),
#  ('global_water_access',),
#  ('location',),
#  ('visits',),
#  ('water_quality',),
#  ('water_source',),
#  ('well_pollution',),
#  ('well_pollution_copy',)]

# %%
# %%sql
#
# UPDATE well_pollution
# SET description = 'Bacteria: E. coli'
# WHERE description = 'Clean Bacteria: E. coli';
#
# UPDATE well_pollution
# SET description = 'Bacteria: Giardia Lamblia'
# WHERE description = 'Clean Bacteria: Giardia Lamblia';
#
# UPDATE well_pollution SET results = 'Contaminated: Biological'
# WHERE biological > 0.01 AND results = 'Clean';
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# []

# %%
# %%sql
#
# SELECT *
# FROM well_pollution
# WHERE description LIKE 'Clean_%' OR(results = 'Clean' AND biological > 0.01)
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 0 rows affected.
# []

# %% [markdown]
# # Maji Ndogo: From analysis to action

# %% [markdown]
# ## Part 2: Clustering data to unveil Maji Ndogo's water crisis

# %% [markdown]
# ### Task 1: Cleaning our data

# %% [markdown]
# Cleaning the email column

# %%
# %%sql
#
# SELECT *
# FROM employee
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 5 rows affected.
# [(0, 'Amara Jengo', '+99637993287', 'amara.jengo@ndogowater.gov', '36 Pwani Mchangani Road', 'Sokoto', 'Ilanga', 'Field Surveyor'),
#  (1, 'Bello Azibo', '+99643864786', 'bello.azibo@ndogowater.gov', '129 Ziwa La Kioo Road', 'Kilimani', 'Rural', 'Field Surveyor'),
#  (2, 'Bakari Iniko', '+99222599041', 'bakari.iniko@ndogowater.gov', '18 Mlima Tazama Avenue', 'Hawassa', 'Rural', 'Field Surveyor'),
#  (3, 'Malachi Mavuso', '+99945849900', 'malachi.mavuso@ndogowater.gov', '100 Mogadishu Road', 'Akatsi', 'Lusaka', 'Field Surveyor'),
#  (4, 'Cheche Buhle', '+99381679640', 'cheche.buhle@ndogowater.gov', '1 Savanna Street', 'Akatsi', 'Rural', 'Field Surveyor')]

# %%
# %%sql
#
# SELECT
#     CONCAT(
#         LOWER(REPLACE(employee_name, ' ', '.')), '@ndogowater.gov'
#     ) AS new_email
#
# FROM employee
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 5 rows affected.
# [('amara.jengo@ndogowater.gov',),
#  ('bello.azibo@ndogowater.gov',),
#  ('bakari.iniko@ndogowater.gov',),
#  ('malachi.mavuso@ndogowater.gov',),
#  ('cheche.buhle@ndogowater.gov',)]

# %%
# %%sql
#
# UPDATE employee
# SET email = CONCAT(LOWER(REPLACE(employee_name, ' ', '.')), '@ndogowater.gov')
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 56 rows affected.
# []

# %%
# %%sql
#
# SELECT email
# FROM employee
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 5 rows affected.
# [('amara.jengo@ndogowater.gov',),
#  ('bello.azibo@ndogowater.gov',),
#  ('bakari.iniko@ndogowater.gov',),
#  ('malachi.mavuso@ndogowater.gov',),
#  ('cheche.buhle@ndogowater.gov',)]

# %% [markdown]
# Cleaning the phone numbers column

# %%
# %%sql
#
# -- Check phone numbers length
# SELECT LENGTH(phone_number)
# FROM employee
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 5 rows affected.
# [(12,), (12,), (12,), (12,), (12,)]

# %%
# %%sql
#
# UPDATE employee
# SET phone_number = TRIM(phone_number)
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 56 rows affected.
# []

# %%
# %%sql
#
# -- Verify length
# SELECT LENGTH(phone_number)
# FROM employee
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 5 rows affected.
# [(12,), (12,), (12,), (12,), (12,)]

# %% [markdown]
# ## 2. Honouring the Workers

# %% [markdown]
# Count employees per town + find the top 3 field surveyors by visits

# %%
# %%sql
#
# -- Number of employees in each town
# SELECT town_name, COUNT(DISTINCT(assigned_employee_id)) AS 'Employee_Count'
# FROM employee
# GROUP BY town_name
# ORDER BY  Employee_Count DESC;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 9 rows affected.
# [('Rural', 29),
#  ('Dahabu', 6),
#  ('Harare', 5),
#  ('Lusaka', 4),
#  ('Zanzibar', 4),
#  ('Ilanga', 3),
#  ('Serowe', 3),
#  ('Kintampo', 1),
#  ('Yaounde', 1)]

# %%
# %%sql
#
# -- Top 3 field surveyors
# SELECT assigned_employee_id, COUNT(*) AS number_of_visits
# FROM visits
# GROUP BY assigned_employee_id
# ORDER BY number_of_visits DESC
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 5 rows affected.
# [(1, 3708), (30, 3676), (34, 3539), (3, 3420), (10, 3407)]

# %%
# %%sql
#
# -- Look up top 3 employee info
# SELECT assigned_employee_id, employee_name, email, phone_number
# FROM employee
# WHERE assigned_employee_id IN(1, 30, 34)
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 3 rows affected.
# [(1, 'Bello Azibo', 'bello.azibo@ndogowater.gov', '+99643864786'),
#  (30, 'Pili Zola', 'pili.zola@ndogowater.gov', '+99822478933'),
#  (34, 'Rudo Imani', 'rudo.imani@ndogowater.gov', '+99046972648')]

# %% [markdown]
# ## 3. Analysing Locations

# %% [markdown]
# Looking at the locations table, let's focus on the province name, town name and location type to understand where the water sources are in Maji Ndogo

# %%
# %%sql
#
# -- Count the number of records per town
# SELECT town_name, COUNT(*) AS records_per_town
# FROM location
# GROUP BY town_name
# ORDER BY records_per_town DESC;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 25 rows affected.
# [('Rural', 23740),
#  ('Harare', 1650),
#  ('Amina', 1090),
#  ('Lusaka', 1070),
#  ('Mrembo', 990),
#  ('Asmara', 930),
#  ('Dahabu', 930),
#  ('Kintampo', 780),
#  ('Ilanga', 780),
#  ('Isiqalo', 770),
#  ('Zuri', 750),
#  ('Amara', 710),
#  ('Majengo', 620),
#  ('Pwani', 520),
#  ('Kofi', 510),
#  ('Serowe', 480),
#  ('Bahari', 470),
#  ('Marang', 460),
#  ('Abidjan', 400),
#  ('Bello', 400),
#  ('Cheche', 370),
#  ('Deka', 350),
#  ('Djenne', 310),
#  ('Zanzibar', 300),
#  ('Yaounde', 270)]

# %%
# %%sql
#
# -- Count the records per province
# SELECT province_name, COUNT(*) AS records_per_province
# FROM location
# GROUP BY province_name
# ORDER BY records_per_province DESC;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 5 rows affected.
# [('Kilimani', 9510),
#  ('Akatsi', 8940),
#  ('Sokoto', 8220),
#  ('Amanzi', 6950),
#  ('Hawassa', 6030)]

# %%
# %%sql
#
# SELECT province_name, town_name, COUNT(*) AS records_per_town
# FROM location
# GROUP BY province_name, town_name
# ORDER BY province_name, records_per_town DESC;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 31 rows affected.
# [('Akatsi', 'Rural', 6290),
#  ('Akatsi', 'Lusaka', 1070),
#  ('Akatsi', 'Harare', 800),
#  ('Akatsi', 'Kintampo', 780),
#  ('Amanzi', 'Rural', 3100),
#  ('Amanzi', 'Asmara', 930),
#  ('Amanzi', 'Dahabu', 930),
#  ('Amanzi', 'Amina', 670),
#  ('Amanzi', 'Pwani', 520),
#  ('Amanzi', 'Abidjan', 400),
#  ('Amanzi', 'Bello', 400),
#  ('Hawassa', 'Rural', 3900),
#  ('Hawassa', 'Serowe', 480),
#  ('Hawassa', 'Amina', 420),
#  ('Hawassa', 'Deka', 350),
#  ('Hawassa', 'Djenne', 310),
#  ('Hawassa', 'Zanzibar', 300),
#  ('Hawassa', 'Yaounde', 270),
#  ('Kilimani', 'Rural', 5440),
#  ('Kilimani', 'Mrembo', 990),
#  ('Kilimani', 'Harare', 850),
#  ('Kilimani', 'Isiqalo', 770),
#  ('Kilimani', 'Zuri', 750),
#  ('Kilimani', 'Amara', 710),
#  ('Sokoto', 'Rural', 5010),
#  ('Sokoto', 'Ilanga', 780),
#  ('Sokoto', 'Majengo', 620),
#  ('Sokoto', 'Kofi', 510),
#  ('Sokoto', 'Bahari', 470),
#  ('Sokoto', 'Marang', 460),
# ...

# %%
# %%sql
#
# -- Records for each location type
# SELECT location_type, COUNT(*) AS num_sources, ROUND(COUNT(*) * 100.0 / SUM(COUNT(*)) OVER(), 0) AS percentage
# FROM location
# GROUP BY location_type
# ORDER BY num_sources DESC;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 2 rows affected.
# [('Rural', 23740, Decimal('60')), ('Urban', 15910, Decimal('40'))]

# %% [markdown]
# ## 4. Diving into sources

# %%
# %%sql
#
# -- Quick view at the sources table
# SELECT *
# FROM water_source
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 5 rows affected.
# [('AkHa00000224', 'tap_in_home', 956),
#  ('AkHa00001224', 'tap_in_home_broken', 930),
#  ('AkHa00002224', 'tap_in_home_broken', 486),
#  ('AkHa00003224', 'well', 364),
#  ('AkHa00004224', 'tap_in_home_broken', 942)]

# %%
# %%sql
#
# -- Explore the types of water sources
# SELECT DISTINCT(type_of_water_source) AS water_source
# FROM water_source
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 5 rows affected.
# [('tap_in_home',),
#  ('tap_in_home_broken',),
#  ('well',),
#  ('shared_tap',),
#  ('river',)]

# %%
# %%sql
#
# -- Get the number of water sources for each type
# SELECT type_of_water_source, COUNT(*) as number_of_sources
# FROM water_source
# GROUP BY type_of_water_source
# ORDER BY number_of_sources DESC;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 5 rows affected.
# [('well', 17383),
#  ('tap_in_home', 7265),
#  ('tap_in_home_broken', 5856),
#  ('shared_tap', 5767),
#  ('river', 3379)]

# %%
# %%sql
#
# -- Average number of people served by each water source
# SELECT type_of_water_source, ROUND(AVG(Number_of_people_served)) AS avg_people_per_source
# FROM water_source
# GROUP BY type_of_water_source
# ORDER BY avg_people_per_source DESC;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 5 rows affected.
# [('shared_tap', Decimal('2071')),
#  ('river', Decimal('699')),
#  ('tap_in_home_broken', Decimal('649')),
#  ('tap_in_home', Decimal('644')),
#  ('well', Decimal('279'))]

# %%
# %%sql
#
# -- Number of people served by each type of water source
# SELECT type_of_water_source, SUM(Number_of_people_served) AS population_served
# FROM water_source
# GROUP BY type_of_water_source
# ORDER BY population_served DESC;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 5 rows affected.
# [('shared_tap', Decimal('11945272')),
#  ('well', Decimal('4841724')),
#  ('tap_in_home', Decimal('4678880')),
#  ('tap_in_home_broken', Decimal('3799720')),
#  ('river', Decimal('2362544'))]

# %% [markdown]
# ## 5. Start of a Solution - Prioritizing Repairs

# %%
# %%sql
#
# -- Overall rank by population served
# SELECT
#     type_of_water_source,
#     SUM(Number_of_people_served) AS people_served,
#     RANK() OVER(ORDER BY SUM(Number_of_people_served) DESC) AS rank_by_population
# FROM water_source
# GROUP BY type_of_water_source
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 5 rows affected.
# [('shared_tap', Decimal('11945272'), 1),
#  ('well', Decimal('4841724'), 2),
#  ('tap_in_home', Decimal('4678880'), 3),
#  ('tap_in_home_broken', Decimal('3799720'), 4),
#  ('river', Decimal('2362544'), 5)]

# %%
# %%sql
#
# -- Per-source priority (excluding home taps - they are already best)
# SELECT
#     source_id,
#     type_of_water_source,
#     Number_of_people_served,
#     DENSE_RANK() OVER(PARTITION BY type_of_water_source ORDER BY Number_of_people_served DESC) AS priority_rank
# FROM water_source
# WHERE type_of_water_source IN('shared_tap', 'well', 'river', 'tap_in_home_broken')
# ORDER BY type_of_water_source
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 5 rows affected.
# [('SoRu34798224', 'river', 998, 1),
#  ('SoRu35837224', 'river', 998, 1),
#  ('SoRu36238224', 'river', 998, 1),
#  ('SoRu36791224', 'river', 998, 1),
#  ('SoRu36880224', 'river', 998, 1)]

# %% [markdown]
# ## 6. Analysing Queues

# %%
# %%sql
#
# -- Overview of the visits table
# SELECT *
# FROM visits
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 5 rows affected.
# [(0, 'SoIl32582', 'SoIl32582224', datetime.datetime(2021, 1, 1, 9, 10), 1, 15, 12),
#  (1, 'KiRu28935', 'KiRu28935224', datetime.datetime(2021, 1, 1, 9, 17), 1, 0, 46),
#  (2, 'HaRu19752', 'HaRu19752224', datetime.datetime(2021, 1, 1, 9, 36), 1, 62, 40),
#  (3, 'AkLu01628', 'AkLu01628224', datetime.datetime(2021, 1, 1, 9, 53), 1, 0, 1),
#  (4, 'AkRu03357', 'AkRu03357224', datetime.datetime(2021, 1, 1, 10, 11), 1, 28, 14)]

# %% [markdown]
# Question 1: How long did the survey take?

# %%
# %%sql
#
# SELECT
#     MAX(time_of_record) AS Ending_time,
#     MIN(time_of_record) AS Starting_time,
#     DATEDIFF(MAX(time_of_record), MIN(time_of_record) ) AS survey_days
# FROM visits
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 1 rows affected.
# [(datetime.datetime(2023, 7, 14, 13, 53), datetime.datetime(2021, 1, 1, 9, 10), 924)]

# %% [markdown]
# Question 2: How long do people have to queue on average in Maji Ndogo?

# %%
# %%sql
#
# SELECT
#     ROUND(AVG(NULLIF(time_in_queue, 0))) AS avg_queue_time
# FROM visits
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 1 rows affected.
# [(Decimal('123'),)]

# %% [markdown]
# Question 3: What is average queue time on different days?

# %%
# %%sql
#
# SELECT
#     DAYNAME(time_in_queue) as day_of_week,
#     ROUND(AVG(time_in_queue)) as avg_queue_time
# FROM visits
# WHERE time_in_queue != 0
# GROUP BY day_of_week
# ORDER BY avg_queue_time DESC
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 8 rows affected.
# [('Friday', Decimal('181')),
#  ('Thursday', Decimal('178')),
#  ('Tuesday', Decimal('177')),
#  ('Wednesday', Decimal('175')),
#  ('Monday', Decimal('173')),
#  ('Saturday', Decimal('173')),
#  ('Sunday', Decimal('169')),
#  (None, Decimal('111'))]

# %% [markdown]
# Question 4: What time during the day do people collect water?

# %%
# %%sql
#
# SELECT
#     TIME_FORMAT(TIME(time_of_record), '%H:00') AS hour_of_day,
#     ROUND(AVG(time_in_queue), 0) as avg_queue_time
# FROM
#     visits
# WHERE time_in_queue != 0
# GROUP BY hour_of_day
# ORDER BY hour_of_day DESC;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 14 rows affected.
# [('19:00', Decimal('168')),
#  ('18:00', Decimal('147')),
#  ('17:00', Decimal('149')),
#  ('16:00', Decimal('114')),
#  ('15:00', Decimal('114')),
#  ('14:00', Decimal('114')),
#  ('13:00', Decimal('115')),
#  ('12:00', Decimal('112')),
#  ('11:00', Decimal('111')),
#  ('10:00', Decimal('114')),
#  ('09:00', Decimal('118')),
#  ('08:00', Decimal('149')),
#  ('07:00', Decimal('149')),
#  ('06:00', Decimal('149'))]

# %%
# %%sql
#
# SELECT
#     TIME_FORMAT(TIME(time_of_record), '%H:00') AS hour_of_day,
#
#     -- Sunday
#     ROUND(AVG(
#         CASE
#         WHEN DAYNAME(time_of_record) = 'Sunday' THEN time_in_queue
#         ELSE NULL
#     END
#     ), 0) AS Sunday,
#
#     -- Monday
#     ROUND(AVG(
#         CASE
#         WHEN DAYNAME(time_of_record) = 'Monday' THEN time_in_queue
#         ELSE NULL
#     END
#     ), 0) AS Monday,
#
#     -- Tuesday
#     ROUND(AVG(
#         CASE
#         WHEN DAYNAME(time_of_record) = 'Tuesday' THEN time_in_queue
#         ELSE NULL
#     END
#     ), 0) AS Tuesday,
#
#     -- Wednesday
#     ROUND(AVG(
#         CASE
#         WHEN DAYNAME(time_of_record) = 'Wednesday' THEN time_in_queue
#         ELSE NULL
#     END
#     ), 0) AS Wednesday,
#
#     -- Thursday
#     ROUND(AVG(
#         CASE
#         WHEN DAYNAME(time_of_record) = 'Thursday' THEN time_in_queue
#         ELSE NULL
#     END
#     ), 0) AS Thursday,
#
#     -- Friday
#     ROUND(AVG(
#         CASE
#         WHEN DAYNAME(time_of_record) = 'Friday' THEN time_in_queue
#         ELSE NULL
#     END
#     ), 0) AS Friday,
#
#     -- Saturday
#     ROUND(AVG(
#         CASE
#         WHEN DAYNAME(time_of_record) = 'Saturday' THEN time_in_queue
#         ELSE NULL
#     END
#     ), 0) AS Saturday
#
# FROM
#     visits
# WHERE
#     time_in_queue != 0
# GROUP BY
#     hour_of_day
# ORDER BY
#     hour_of_day
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 14 rows affected.
# [('06:00', Decimal('79'), Decimal('190'), Decimal('134'), Decimal('112'), Decimal('134'), Decimal('153'), Decimal('247')),
#  ('07:00', Decimal('82'), Decimal('186'), Decimal('128'), Decimal('111'), Decimal('139'), Decimal('156'), Decimal('247')),
#  ('08:00', Decimal('86'), Decimal('183'), Decimal('130'), Decimal('119'), Decimal('129'), Decimal('153'), Decimal('247')),
#  ('09:00', Decimal('84'), Decimal('127'), Decimal('105'), Decimal('94'), Decimal('99'), Decimal('107'), Decimal('252')),
#  ('10:00', Decimal('83'), Decimal('119'), Decimal('99'), Decimal('89'), Decimal('95'), Decimal('112'), Decimal('259')),
#  ('11:00', Decimal('78'), Decimal('115'), Decimal('102'), Decimal('86'), Decimal('99'), Decimal('104'), Decimal('236')),
#  ('12:00', Decimal('78'), Decimal('115'), Decimal('97'), Decimal('88'), Decimal('96'), Decimal('109'), Decimal('239')),
# ...
